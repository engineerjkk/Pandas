# %%
import pandas as pd
import numpy as  np

# %%
import seaborn

p=seaborn.load_dataset('penguins')

# %% [markdown]
# 1. NA값 처리
# 2. 데이터 타입 확인/ 변환
# 3. Describe 활용
# 4. 시각화(단변량, 다변량) 및 관계성 체크

# %%
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
new_p=p.dropna()

# %%
print(new_p.species.value_counts(),
     new_p.island.value_counts(),
     new_p.sex.value_counts())
# Out:
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: species, dtype: int64 Biscoe       163
# Dream        123
# Torgersen     47
# Name: island, dtype: int64 Male      168
# Female    165
# Name: sex, dtype: int64

# %%
new_p.loc[:,'island']=new_p.island.copy().astype('category')

# %%
new_p.island.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
new_p.island.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 9주차

# %%
college=pd.read_csv('data/college.csv')
cols=college.columns
cols
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
cols.values
# Out:
# array(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY',
#        'RELAFFIL', 'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS',
#        'UGDS_WHITE', 'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN',
#        'UGDS_NHPI', 'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF',
#        'CURROPER', 'PCTPELL', 'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10',
#        'GRAD_DEBT_MDN_SUPP'], dtype=object)

# %%
cols[1::4]
# Out:
# Index(['CITY', 'WOMENONLY', 'DISTANCEONLY', 'UGDS_HISP', 'UGDS_2MOR',
#        'CURROPER', 'MD_EARN_WNE_P10'],
#       dtype='object')

# %%
print(cols.min(),cols.max(),cols.isnull().sum())
# Out:
# CITY WOMENONLY 0

# %%
print(cols.min(),cols.max(),cols.hasnans) #have, 즉 결측치를 갖고있니? =없다!
# Out:
# CITY WOMENONLY False

# %%
cols.sort_values()
# Out:
# Index(['CITY', 'CURROPER', 'DISTANCEONLY', 'GRAD_DEBT_MDN_SUPP', 'HBCU',
#        'INSTNM', 'MD_EARN_WNE_P10', 'MENONLY', 'PCTFLOAN', 'PCTPELL',
#        'PPTUG_EF', 'RELAFFIL', 'SATMTMID', 'SATVRMID', 'STABBR', 'UG25ABV',
#        'UGDS', 'UGDS_2MOR', 'UGDS_AIAN', 'UGDS_ASIAN', 'UGDS_BLACK',
#        'UGDS_HISP', 'UGDS_NHPI', 'UGDS_NRA', 'UGDS_UNKN', 'UGDS_WHITE',
#        'WOMENONLY'],
#       dtype='object')

# %% [markdown]
# 컬럼 이름에 변화를 주고 싶을 때 아래와 같이 가능합니다.

# %%
cols+'_new'
# Out:
# Index(['INSTNM_new', 'CITY_new', 'STABBR_new', 'HBCU_new', 'MENONLY_new',
#        'WOMENONLY_new', 'RELAFFIL_new', 'SATVRMID_new', 'SATMTMID_new',
#        'DISTANCEONLY_new', 'UGDS_new', 'UGDS_WHITE_new', 'UGDS_BLACK_new',
#        'UGDS_HISP_new', 'UGDS_ASIAN_new', 'UGDS_AIAN_new', 'UGDS_NHPI_new',
#        'UGDS_2MOR_new', 'UGDS_NRA_new', 'UGDS_UNKN_new', 'PPTUG_EF_new',
#        'CURROPER_new', 'PCTPELL_new', 'PCTFLOAN_new', 'UG25ABV_new',
#        'MD_EARN_WNE_P10_new', 'GRAD_DEBT_MDN_SUPP_new'],
#       dtype='object')

# %%
cols[1:5]+'_new'
# Out:
# Index(['CITY_new', 'STABBR_new', 'HBCU_new', 'MENONLY_new'], dtype='object')

# %% [markdown]
# G보다 큰건 트루 !

# %%
cols>'G'
# Out:
# array([ True, False,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True])

# %%
cols[1]='CITY1'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-7865eaa9941e> in <module>
# ----> 1 cols[1]='CITY1'
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    4079
#    4080     def __setitem__(self, key, value):
# -> 4081         raise TypeError("Index does not support mutable operations")
#    4082
#    4083     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %% [markdown]
# ## 집합의 개념을 사용할 수 있습니다.
# ## 합집합 = Union

# %%
c1=cols[:4]
c2=cols[2:6]
c1.union(c2)
# Out:
# Index(['CITY', 'HBCU', 'INSTNM', 'MENONLY', 'STABBR', 'WOMENONLY'], dtype='object')

# %% [markdown]
# # 교집합 = intersection

# %%
c1.intersection(c2)
# Out:
# Index(['STABBR', 'HBCU'], dtype='object')

# %%
c1.difference(c2)
# Out:
# Index(['CITY', 'INSTNM'], dtype='object')

# %%
s1=pd.Series(index=list('aaab'),data=np.arange(4))
s2=pd.Series(index=list('cababb'),data=np.arange(6))

# %%
s1
# Out:
# a    0
# a    1
# a    2
# b    3
# dtype: int32

# %%
s2
# Out:
# c    0
# a    1
# b    2
# a    3
# b    4
# b    5
# dtype: int32

# %%
s1+s2
# Out:
# a    1.0
# a    3.0
# a    2.0
# a    4.0
# a    3.0
# a    5.0
# b    5.0
# b    7.0
# b    8.0
# c    NaN
# dtype: float64

# %% [markdown]
# 4개 6개였는데 더하니 길이가 대폭 늘어났다.
# C는 없으니 결측치가 된다. Na+0은 Na!

# %% [markdown]
# 인덱스가 일치하지않는경우에는 카티션 프로덕트를 만드는게 판다스의 기본 원칙이다.

# %%
s1=pd.Series(index=list('aaabb'),data=np.arange(5))
s2=pd.Series(index=list('bbaaa'),data=np.arange(5))

# %%
s1+s2
# Out:
# a    2
# a    3
# a    4
# a    3
# a    4
# a    5
# a    4
# a    5
# a    6
# b    3
# b    4
# b    4
# b    5
# dtype: int32

# %%
s1=pd.Series(index=list('ab'),data=np.arange(2))
s2=pd.Series(index=list('ba'),data=np.arange(2))
s1+s2
# Out:
# a    1
# b    1
# dtype: int32

# %% [markdown]
# 그러니까 여러 컬럼을 조작할 때, 인덱스가 같은지 확인하는 것이 중요합니다.
# 만약 이러한 상황을 고려하지 않는다면 인덱스가 무진장 많아지는 현상을 볼 수 있습니다.
# 아래와 같이 말입니다!

# %%
emp=pd.read_csv('data/employee.csv',index_col='RACE')
emp.head()
# Out:
#                  UNIQUE_ID               POSITION_TITLE  \
# RACE
# Hispanic/Latino          0  ASSISTANT DIRECTOR (EX LVL)
# Hispanic/Latino          1            LIBRARY ASSISTANT
# White                    2               POLICE OFFICER
# White                    3            ENGINEER/OPERATOR
# White                    4                  ELECTRICIAN
#
#                                     DEPARTMENT  BASE_SALARY EMPLOYMENT_TYPE  \
# RACE
# Hispanic/Latino    Municipal Courts Department     121862.0       Full Time
# Hispanic/Latino                        Library      26125.0       Full Time
# White            Houston Police Department-HPD      45279.0       Full Time
# White            Houston Fire Department (HFD)      63166.0       Full Time
# White              General Services Department      56347.0       Full Time
#
#                  GENDER EMPLOYMENT_STATUS   HIRE_DATE    JOB_DATE
# RACE
# Hispanic/Latino  Female            Active  2006-06-12  2012-10-13
# Hispanic/Latino  Female            Active  2000-07-19  2010-09-18
# White              Male            Active  2015-02-03  2015-02-03
# White              Male            Active  1982-02-08  1991-05-25
# White              Male            Active  1989-06-19  1994-10-22

# %%
salary1=emp['BASE_SALARY']
salary2=emp['BASE_SALARY']
salary1 is salary2
# Out:
# True

# %% [markdown]
# 얕은 복사가 되니 같은 것을 가리킵니다.
# 깊은 복사를 하기 위해 .copy 를 사용합니다.

# %%
salary2=emp['BASE_SALARY'].copy()
salary1 is salary2
# Out:
# False

# %% [markdown]
# 메모리 주소를 확인해보겠습니다. salary1과 salary2가 다른 메모리 주소를 가지고있음을 알 수 있습니다.

# %%
print(id(salary2),id(salary1),id(emp['BASE_SALARY']))
# Out:
# 2084257913872 2084257839328 2084257839328

# %%
salary1=salary1.sort_index()

# %%
salary1+salary2
# Out:
# RACE
# American Indian or Alaskan Native    138702.0
# American Indian or Alaskan Native    156710.0
# American Indian or Alaskan Native    176891.0
# American Indian or Alaskan Native    159594.0
# American Indian or Alaskan Native    127734.0
#                                        ...
# NaN                                   68024.0
# NaN                                   56048.0
# NaN                                   56790.0
# NaN                                       NaN
# NaN                                   56048.0
# Name: BASE_SALARY, Length: 1175424, dtype: float64

# %%
salary1
# Out:
# RACE
# American Indian or Alaskan Native    78355.0
# American Indian or Alaskan Native    26125.0
# American Indian or Alaskan Native    98536.0
# American Indian or Alaskan Native        NaN
# American Indian or Alaskan Native    55461.0
#                                       ...
# NaN                                  40000.0
# NaN                                  28024.0
# NaN                                  28766.0
# NaN                                      NaN
# NaN                                  28024.0
# Name: BASE_SALARY, Length: 2000, dtype: float64

# %%
salary1+salary2
# Out:
# RACE
# American Indian or Alaskan Native    138702.0
# American Indian or Alaskan Native    156710.0
# American Indian or Alaskan Native    176891.0
# American Indian or Alaskan Native    159594.0
# American Indian or Alaskan Native    127734.0
#                                        ...
# NaN                                   68024.0
# NaN                                   56048.0
# NaN                                   56790.0
# NaN                                       NaN
# NaN                                   56048.0
# Name: BASE_SALARY, Length: 1175424, dtype: float64

# %%
salary1+salary1
# Out:
# RACE
# American Indian or Alaskan Native    156710.0
# American Indian or Alaskan Native     52250.0
# American Indian or Alaskan Native    197072.0
# American Indian or Alaskan Native         NaN
# American Indian or Alaskan Native    110922.0
#                                        ...
# NaN                                   80000.0
# NaN                                   56048.0
# NaN                                   57532.0
# NaN                                       NaN
# NaN                                   56048.0
# Name: BASE_SALARY, Length: 2000, dtype: float64

# %% [markdown]
# sort한 뒤에 더하면 length가 유지됩니다.

# %%
salary1+salary2.sort_index()
# Out:
# RACE
# American Indian or Alaskan Native    156710.0
# American Indian or Alaskan Native     52250.0
# American Indian or Alaskan Native    197072.0
# American Indian or Alaskan Native         NaN
# American Indian or Alaskan Native    110922.0
#                                        ...
# NaN                                   80000.0
# NaN                                   56048.0
# NaN                                   57532.0
# NaN                                       NaN
# NaN                                   56048.0
# Name: BASE_SALARY, Length: 2000, dtype: float64

# %%
baseball_14=pd.read_csv('data/baseball14.csv',index_col='playerID')
baseball_15=pd.read_csv('data/baseball15.csv',index_col='playerID')
baseball_16=pd.read_csv('data/baseball16.csv',index_col='playerID')

# %%
baseball_14.head()
# Out:
#            yearID  stint teamID lgID    G   AB   R    H  2B  3B  ...   RBI  \
# playerID                                                         ...
# altuvjo01    2014      1    HOU   AL  158  660  85  225  47   3  ...  59.0
# cartech02    2014      1    HOU   AL  145  507  68  115  21   1  ...  88.0
# castrja01    2014      1    HOU   AL  126  465  43  103  21   2  ...  56.0
# corpoca01    2014      1    HOU   AL   55  170  22   40   6   0  ...  19.0
# dominma01    2014      1    HOU   AL  157  564  51  121  17   0  ...  57.0
#
#              SB   CS  BB     SO  IBB  HBP   SH   SF  GIDP
# playerID
# altuvjo01  56.0  9.0  36   53.0  7.0  5.0  1.0  5.0  20.0
# cartech02   5.0  2.0  56  182.0  6.0  5.0  0.0  4.0  12.0
# castrja01   1.0  0.0  34  151.0  1.0  9.0  1.0  3.0  11.0
# corpoca01   0.0  0.0  14   37.0  0.0  3.0  1.0  2.0   3.0
# dominma01   0.0  1.0  29  125.0  2.0  5.0  2.0  7.0  23.0
#
# [5 rows x 21 columns]

# %%
baseball_14.index.difference(baseball_15.index)
# Out:
# Index(['corpoca01', 'dominma01', 'fowlede01', 'grossro01', 'guzmaje01',
#        'hoeslj01', 'krausma01', 'preslal01', 'singljo02'],
#       dtype='object', name='playerID')

# %%
baseball_14.index
# Out:
# Index(['altuvjo01', 'cartech02', 'castrja01', 'corpoca01', 'dominma01',
#        'fowlede01', 'gonzama01', 'grossro01', 'guzmaje01', 'hoeslj01',
#        'krausma01', 'marisja01', 'preslal01', 'singljo02', 'springe01',
#        'villajo01'],
#       dtype='object', name='playerID')

# %% [markdown]
# 그렇다면 14년도에 뛰었지만 15년도에 뛰지않은 사람을 보기 위해서는 14-15!

# %%
baseball_15.index
# Out:
# Index(['altuvjo01', 'cartech02', 'castrja01', 'congeha01', 'correca01',
#        'gattiev01', 'gomezca01', 'gonzama01', 'lowrije01', 'marisja01',
#        'rasmuco01', 'springe01', 'tuckepr01', 'valbulu01', 'villajo01'],
#       dtype='object', name='playerID')

# %%
baseball_14.index.difference(baseball_15.index)
# Out:
# Index(['corpoca01', 'dominma01', 'fowlede01', 'grossro01', 'guzmaje01',
#        'hoeslj01', 'krausma01', 'preslal01', 'singljo02'],
#       dtype='object', name='playerID')

# %%
baseball_15.index.difference(baseball_14.index)
# Out:
# Index(['congeha01', 'correca01', 'gattiev01', 'gomezca01', 'lowrije01',
#        'rasmuco01', 'tuckepr01', 'valbulu01'],
#       dtype='object', name='playerID')

# %%
hits_14=baseball_14['H']
hits_15=baseball_15['H']
hits_16=baseball_16['H']

hits_14.head()
# Out:
# playerID
# altuvjo01    225
# cartech02    115
# castrja01    103
# corpoca01     40
# dominma01    121
# Name: H, dtype: int64

# %% [markdown]
# 두 년도를 더해봅니다. 두개년도의 안타수를 더합니다.
# 한해만 들어가있을수도, 두해 둘다 들어가있을 수도 있습니다.
# fillNa처리가 안되므로 add를 사용합니다

# %%
(hits_14+hits_15).head()
# Out:
# playerID
# altuvjo01    425.0
# cartech02    193.0
# castrja01    174.0
# congeha01      NaN
# corpoca01      NaN
# Name: H, dtype: float64

# %%
hits_total=hits_14.add(hits_15,fill_value=0).add(hits_16,fill_value=0)

# %%
hits_total.head()
# Out:
# playerID
# altuvjo01    641.0
# bregmal01     53.0
# cartech02    193.0
# castrja01    243.0
# congeha01     46.0
# Name: H, dtype: float64

# %%
hits_total=hits_14.add(hits_15,fill_value=0).add(hits_16,fill_value=0)
hits_total.head()
# Out:
# playerID
# altuvjo01    641.0
# bregmal01     53.0
# cartech02    193.0
# castrja01    243.0
# congeha01     46.0
# Name: H, dtype: float64

# %% [markdown]
# 한 해만 등장했던 사람들도 전부 등장합니다.

# %%
s=pd.Series(index=list('abcd'),data=[np.nan,3,np.nan,1])
s1=pd.Series(index=list('abc'),data=[np.nan,6,10])

# %%
s
# Out:
# a    NaN
# b    3.0
# c    NaN
# d    1.0
# dtype: float64

# %%
s1
# Out:
# a     NaN
# b     6.0
# c    10.0
# dtype: float64

# %%
s.add(s1,fill_value=5)
# Out:
# a     NaN
# b     9.0
# c    15.0
# d     6.0
# dtype: float64

# %% [markdown]
# Series의 덧셈에서 나아가, DF의 덧셈도 인덱스를 맞춰 진행할 수 있습니다.
# 다만, 카티션 곱!을 조심해야합니다.
# df는 컬럼과 인덱스 데이터, 시리즈는 인덱스 데이터죠. 차이점은 컬럼이었죠

# %%
df_14=baseball_14[['G','AB','R','H']]
df_15=baseball_15[['AB','R','H','HR']]

# %%
(df_14+df_15).head(10)
# Out:
#                AB   G      H  HR      R
# playerID
# altuvjo01  1298.0 NaN  425.0 NaN  171.0
# cartech02   898.0 NaN  193.0 NaN  118.0
# castrja01   802.0 NaN  174.0 NaN   81.0
# congeha01     NaN NaN    NaN NaN    NaN
# corpoca01     NaN NaN    NaN NaN    NaN
# correca01     NaN NaN    NaN NaN    NaN
# dominma01     NaN NaN    NaN NaN    NaN
# fowlede01     NaN NaN    NaN NaN    NaN
# gattiev01     NaN NaN    NaN NaN    NaN
# gomezca01     NaN NaN    NaN NaN    NaN

# %%
(df_14+df_15)
# Out:
#                AB   G      H  HR      R
# playerID
# altuvjo01  1298.0 NaN  425.0 NaN  171.0
# cartech02   898.0 NaN  193.0 NaN  118.0
# castrja01   802.0 NaN  174.0 NaN   81.0
# congeha01     NaN NaN    NaN NaN    NaN
# corpoca01     NaN NaN    NaN NaN    NaN
# correca01     NaN NaN    NaN NaN    NaN
# dominma01     NaN NaN    NaN NaN    NaN
# fowlede01     NaN NaN    NaN NaN    NaN
# gattiev01     NaN NaN    NaN NaN    NaN
# gomezca01     NaN NaN    NaN NaN    NaN
# gonzama01   629.0 NaN  175.0 NaN   77.0
# grossro01     NaN NaN    NaN NaN    NaN
# guzmaje01     NaN NaN    NaN NaN    NaN
# hoeslj01      NaN NaN    NaN NaN    NaN
# krausma01     NaN NaN    NaN NaN    NaN
# lowrije01     NaN NaN    NaN NaN    NaN
# marisja01   512.0 NaN  127.0 NaN   64.0
# preslal01     NaN NaN    NaN NaN    NaN
# rasmuco01     NaN NaN    NaN NaN    NaN
# singljo02     NaN NaN    NaN NaN    NaN
# springe01   683.0 NaN  175.0 NaN  104.0
# tuckepr01     NaN NaN    NaN NaN    NaN
# valbulu01     NaN NaN    NaN NaN    NaN
# villajo01   379.0 NaN   88.0 NaN   49.0

# %% [markdown]
# Add를 쓰면 좀 나아지겠지만, 문제를 해결해주진 못합니다.
# 14/15년 중 한 해에만 기록이 있으면 문제가 되는 것이죠.

# %%
(
    df_14.add(df_15,fill_value=0)
    .head(10)
    .style.highlight_null('yellow')#이렇게 쓰면 최종 결과에서 null 값을 더  잘 보여줍니다.
)
# Out:
# <style  type="text/css" >
# #T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row3_col1,#T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row4_col3,#T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row5_col1,#T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row6_col3,#T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row7_col3,#T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row8_col1,#T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row9_col1{
#             background-color:  yellow;
#         }</style><table id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AB</th>        <th class="col_heading level0 col1" >G</th>        <th class="col_heading level0 col2" >H</th>        <th class="col_heading level0 col3" >HR</th>        <th class="col_heading level0 col4" >R</th>    </tr>    <tr>        <th class="index_name level0" >playerID</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62level0_row0" class="row_heading level0 row0" >altuvjo01</th>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row0_col0" class="data row0 col0" >1298.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row0_col1" class="data row0 col1" >158.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row0_col2" class="data row0 col2" >425.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row0_col3" class="data row0 col3" >15.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row0_col4" class="data row0 col4" >171.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62level0_row1" class="row_heading level0 row1" >cartech02</th>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row1_col0" class="data row1 col0" >898.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row1_col1" class="data row1 col1" >145.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row1_col2" class="data row1 col2" >193.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row1_col3" class="data row1 col3" >24.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row1_col4" class="data row1 col4" >118.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62level0_row2" class="row_heading level0 row2" >castrja01</th>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row2_col0" class="data row2 col0" >802.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row2_col1" class="data row2 col1" >126.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row2_col2" class="data row2 col2" >174.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row2_col3" class="data row2 col3" >11.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row2_col4" class="data row2 col4" >81.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62level0_row3" class="row_heading level0 row3" >congeha01</th>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row3_col0" class="data row3 col0" >201.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row3_col1" class="data row3 col1" >nan</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row3_col2" class="data row3 col2" >46.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row3_col3" class="data row3 col3" >11.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row3_col4" class="data row3 col4" >25.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62level0_row4" class="row_heading level0 row4" >corpoca01</th>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row4_col0" class="data row4 col0" >170.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row4_col1" class="data row4 col1" >55.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row4_col2" class="data row4 col2" >40.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row4_col3" class="data row4 col3" >nan</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row4_col4" class="data row4 col4" >22.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62level0_row5" class="row_heading level0 row5" >correca01</th>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row5_col0" class="data row5 col0" >387.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row5_col1" class="data row5 col1" >nan</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row5_col2" class="data row5 col2" >108.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row5_col3" class="data row5 col3" >22.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row5_col4" class="data row5 col4" >52.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62level0_row6" class="row_heading level0 row6" >dominma01</th>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row6_col0" class="data row6 col0" >564.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row6_col1" class="data row6 col1" >157.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row6_col2" class="data row6 col2" >121.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row6_col3" class="data row6 col3" >nan</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row6_col4" class="data row6 col4" >51.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62level0_row7" class="row_heading level0 row7" >fowlede01</th>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row7_col0" class="data row7 col0" >434.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row7_col1" class="data row7 col1" >116.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row7_col2" class="data row7 col2" >120.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row7_col3" class="data row7 col3" >nan</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row7_col4" class="data row7 col4" >61.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62level0_row8" class="row_heading level0 row8" >gattiev01</th>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row8_col0" class="data row8 col0" >566.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row8_col1" class="data row8 col1" >nan</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row8_col2" class="data row8 col2" >139.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row8_col3" class="data row8 col3" >27.000000</td>
#                         <td id="T_ab294f4c_ab0d_11eb_993a_e864f0ea9c62row8_col4" class="data row8 col4" >66.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_ab294f4c_ab0d_11eb_9

# %% [markdown]
# DF에 새 열을 추가할 때엔, 인덱스가 먼저 정렬이 됩니다. 여기선 SALARY에 대한 정보를 추가해 보겠습니다.
# 1. 인덱스가 정렬되고, 정렬된 상태에서
# 2. 열이 추가가 된다.

# %%
dept_sal=emp[['DEPARTMENT','BASE_SALARY']]

# %%
dept_sal=dept_sal.sort_values(['DEPARTMENT','BASE_SALARY'],
                             ascending=[True,False])

# %%
max_dept_sal=dept_sal.drop_duplicates(subset='DEPARTMENT')
max_dept_sal.head()
# Out:
#                                              DEPARTMENT  BASE_SALARY
# RACE
# White                        Admn. & Regulatory Affairs     140416.0
# Hispanic/Latino                City Controller's Office      64251.0
# Black or African American                  City Council     100000.0
# Hispanic/Latino            Convention and Entertainment      38397.0
# Black or African American   Dept of Neighborhoods (DON)      89221.0

# %% [markdown]
# 위 정보를 합치기 위해, 두 DF의 인덱스를 맞춰줍니다.

# %%
max_dept_sal=max_dept_sal.set_index('DEPARTMENT')
emp=emp.set_index('DEPARTMENT')

# %%
emp=emp.assign(MAX_DEPT_SALARY=max_dept_sal['BASE_SALARY'])

# %%
emp
# Out:
#                                UNIQUE_ID               POSITION_TITLE  \
# DEPARTMENT
# Municipal Courts Department            0  ASSISTANT DIRECTOR (EX LVL)
# Library                                1            LIBRARY ASSISTANT
# Houston Police Department-HPD          2               POLICE OFFICER
# Houston Fire Department (HFD)          3            ENGINEER/OPERATOR
# General Services Department            4                  ELECTRICIAN
# ...                                  ...                          ...
# Houston Police Department-HPD       1995               POLICE OFFICER
# Houston Fire Department (HFD)       1996       COMMUNICATIONS CAPTAIN
# Houston Police Department-HPD       1997               POLICE OFFICER
# Houston Police Department-HPD       1998               POLICE OFFICER
# Houston Fire Department (HFD)       1999                 FIRE FIGHTER
#
#                                BASE_SALARY EMPLOYMENT_TYPE  GENDER  \
# DEPARTMENT
# Municipal Courts Department       121862.0       Full Time  Female
# Library                            26125.0       Full Time  Female
# Houston Police Department-HPD      45279.0       Full Time    Male
# Houston Fire Department (HFD)      63166.0       Full Time    Male
# General Services Department        56347.0       Full Time    Male
# ...                                    ...             ...     ...
# Houston Police Department-HPD      43443.0       Full Time    Male
# Houston Fire Department (HFD)      66523.0       Full Time    Male
# Houston Police Department-HPD      43443.0       Full Time    Male
# Houston Police Department-HPD      55461.0       Full Time    Male
# Houston Fire Department (HFD)      51194.0       Full Time    Male
#
#                               EMPLOYMENT_STATUS   HIRE_DATE    JOB_DATE  \
# DEPARTMENT
# Municipal Courts Department              Active  2006-06-12  2012-10-13
# Library                                  Active  2000-07-19  2010-09-18
# Houston Police Department-HPD            Active  2015-02-03  2015-02-03
# Houston Fire Department (HFD)            Active  1982-02-08  1991-05-25
# General Services Department              Active  1989-06-19  1994-10-22
# ...                                         ...         ...         ...
# Houston Police Department-HPD            Active  2014-06-09  2015-06-09
# Houston Fire Department (HFD)            Active  2003-09-02  2013-10-06
# Houston Police Department-HPD            Active  2014-10-13  2015-10-13
# Houston Police Department-HPD            Active  2009-01-20  2011-07-02
# Houston Fire Department (HFD)            Active  2009-01-12  2010-07-12
#
#                                MAX_DEPT_SALARY
# DEPARTMENT
# Municipal Courts Department           121862.0
# Library                               107763.0
# Houston Police Department-HPD         199596.0
# Houston Fire Department (HFD)         210588.0
# General Services Department            89194.0
# ...                                        ...
# Houston Police Department-HPD         199596.0
# Houston Fire Department (HFD)         210588.0
# Houston Police Department-HPD         199596.0
# Houston Police Department-HPD         199596.0
# Houston Fire Department (HFD)         210588.0
#
# [2000 rows x 9 columns]

# %% [markdown]
# 위의 작업을 차근차근해보겠습니다.
# emp에서 부서별 최고 급여를 찾은 뒤, 자신의 부서에서 가장 높은 급여를 컬럼으로 포함시키는 것입니다.
# 이것은 department가 겹치지 않았기 때문에 가능한데, 만약 겹치는(중복된) 부서 이름이 등장하면 카티션 곱이 생성되었을 것입니다.
# 그런데 이렇게 긴~코드를 작성하는 것은 귀찮으니까, **간단한 아래의 코드**를 보겠습니다.

# %%
emp=pd.read_csv('data/employee.csv')

# %% [markdown]
# duplicate보다 groupby가 더 깔끔할겁니다. BASE_SALARY를 선택하고 그다음에 transform은 뒤에있는 함수명을 가져올때 인덱스를 유지할 수 있다. 그 행을 찾아서 가져오기때문에 transform을 씁니다.

# %%
max_sal=(
emp
.groupby('DEPARTMENT')
.BASE_SALARY
.transform('max')
)

# %%
max_sal
# Out:
# 0       121862.0
# 1       107763.0
# 2       199596.0
# 3       210588.0
# 4        89194.0
#           ...
# 1995    199596.0
# 1996    210588.0
# 1997    199596.0
# 1998    199596.0
# 1999    210588.0
# Name: BASE_SALARY, Length: 2000, dtype: float64

# %%
emp.assign(max_sal=max_sal)
# Out:
#       UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0             0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1             1            LIBRARY ASSISTANT                        Library
# 2             2               POLICE OFFICER  Houston Police Department-HPD
# 3             3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4             4                  ELECTRICIAN    General Services Department
# ...         ...                          ...                            ...
# 1995       1995               POLICE OFFICER  Houston Police Department-HPD
# 1996       1996       COMMUNICATIONS CAPTAIN  Houston Fire Department (HFD)
# 1997       1997               POLICE OFFICER  Houston Police Department-HPD
# 1998       1998               POLICE OFFICER  Houston Police Department-HPD
# 1999       1999                 FIRE FIGHTER  Houston Fire Department (HFD)
#
#       BASE_SALARY                       RACE EMPLOYMENT_TYPE  GENDER  \
# 0        121862.0            Hispanic/Latino       Full Time  Female
# 1         26125.0            Hispanic/Latino       Full Time  Female
# 2         45279.0                      White       Full Time    Male
# 3         63166.0                      White       Full Time    Male
# 4         56347.0                      White       Full Time    Male
# ...           ...                        ...             ...     ...
# 1995      43443.0                      White       Full Time    Male
# 1996      66523.0  Black or African American       Full Time    Male
# 1997      43443.0                      White       Full Time    Male
# 1998      55461.0     Asian/Pacific Islander       Full Time    Male
# 1999      51194.0            Hispanic/Latino       Full Time    Male
#
#      EMPLOYMENT_STATUS   HIRE_DATE    JOB_DATE   max_sal
# 0               Active  2006-06-12  2012-10-13  121862.0
# 1               Active  2000-07-19  2010-09-18  107763.0
# 2               Active  2015-02-03  2015-02-03  199596.0
# 3               Active  1982-02-08  1991-05-25  210588.0
# 4               Active  1989-06-19  1994-10-22   89194.0
# ...                ...         ...         ...       ...
# 1995            Active  2014-06-09  2015-06-09  199596.0
# 1996            Active  2003-09-02  2013-10-06  210588.0
# 1997            Active  2014-10-13  2015-10-13  199596.0
# 1998            Active  2009-01-20  2011-07-02  199596.0
# 1999            Active  2009-01-12  2010-07-12  210588.0
#
# [2000 rows x 11 columns]

# %%
max_sal
# Out:
# 0       121862.0
# 1       107763.0
# 2       199596.0
# 3       210588.0
# 4        89194.0
#           ...
# 1995    199596.0
# 1996    210588.0
# 1997    199596.0
# 1998    199596.0
# 1999    210588.0
# Name: BASE_SALARY, Length: 2000, dtype: float64

# %%
max_sal=(
emp.groupby('DEPARTMENT')
.BASE_SALARY
.max())

# %%
max_sal
# Out:
# DEPARTMENT
# Admn. & Regulatory Affairs        140416.0
# City Controller's Office           64251.0
# City Council                      100000.0
# Convention and Entertainment       38397.0
# Dept of Neighborhoods (DON)        89221.0
# Finance                            96272.0
# Fleet Management Department       125884.0
# General Services Department        89194.0
# Health & Human Services           180416.0
# Housing and Community Devp.        98536.0
# Houston Airport System (HAS)      186192.0
# Houston Emergency Center (HEC)     84456.0
# Houston Fire Department (HFD)     210588.0
# Houston Information Tech Svcs     102019.0
# Houston Police Department-HPD     199596.0
# Human Resources Dept.             110547.0
# Legal Department                  275000.0
# Library                           107763.0
# Mayor's Office                    120750.0
# Municipal Courts Department       121862.0
# Parks & Recreation                 85055.0
# Planning & Development             68762.0
# Public Works & Engineering-PWE    178331.0
# Solid Waste Management            110005.0
# Name: BASE_SALARY, dtype: float64

# %%
emp.set_index('DEPARTMENT').assign(max_sal=max_sal)
# Out:
#                                UNIQUE_ID               POSITION_TITLE  \
# DEPARTMENT
# Municipal Courts Department            0  ASSISTANT DIRECTOR (EX LVL)
# Library                                1            LIBRARY ASSISTANT
# Houston Police Department-HPD          2               POLICE OFFICER
# Houston Fire Department (HFD)          3            ENGINEER/OPERATOR
# General Services Department            4                  ELECTRICIAN
# ...                                  ...                          ...
# Houston Police Department-HPD       1995               POLICE OFFICER
# Houston Fire Department (HFD)       1996       COMMUNICATIONS CAPTAIN
# Houston Police Department-HPD       1997               POLICE OFFICER
# Houston Police Department-HPD       1998               POLICE OFFICER
# Houston Fire Department (HFD)       1999                 FIRE FIGHTER
#
#                                BASE_SALARY                       RACE  \
# DEPARTMENT
# Municipal Courts Department       121862.0            Hispanic/Latino
# Library                            26125.0            Hispanic/Latino
# Houston Police Department-HPD      45279.0                      White
# Houston Fire Department (HFD)      63166.0                      White
# General Services Department        56347.0                      White
# ...                                    ...                        ...
# Houston Police Department-HPD      43443.0                      White
# Houston Fire Department (HFD)      66523.0  Black or African American
# Houston Police Department-HPD      43443.0                      White
# Houston Police Department-HPD      55461.0     Asian/Pacific Islander
# Houston Fire Department (HFD)      51194.0            Hispanic/Latino
#
#                               EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# DEPARTMENT
# Municipal Courts Department         Full Time  Female            Active
# Library                             Full Time  Female            Active
# Houston Police Department-HPD       Full Time    Male            Active
# Houston Fire Department (HFD)       Full Time    Male            Active
# General Services Department         Full Time    Male            Active
# ...                                       ...     ...               ...
# Houston Police Department-HPD       Full Time    Male            Active
# Houston Fire Department (HFD)       Full Time    Male            Active
# Houston Police Department-HPD       Full Time    Male            Active
# Houston Police Department-HPD       Full Time    Male            Active
# Houston Fire Department (HFD)       Full Time    Male            Active
#
#                                 HIRE_DATE    JOB_DATE   max_sal
# DEPARTMENT
# Municipal Courts Department    2006-06-12  2012-10-13  121862.0
# Library                        2000-07-19  2010-09-18  107763.0
# Houston Police Department-HPD  2015-02-03  2015-02-03  199596.0
# Houston Fire Department (HFD)  1982-02-08  1991-05-25  210588.0
# General Services Department    1989-06-19  1994-10-22   89194.0
# ...                                   ...         ...       ...
# Houston Police Department-HPD  2014-06-09  2015-06-09  199596.0
# Houston Fire Department (HFD)  2003-09-02  2013-10-06  210588.0
# Houston Police Department-HPD  2014-10-13  2015-10-13  199596.0
# Houston Police Department-HPD  2009-01-20  2011-07-02  199596.0
# Houston Fire Department (HFD)  2009-01-12  2010-07-12  210588.0
#
# [2000 rows x 10 columns]

# %%
emp.assign(max_sal=max_sal)
# Out:
#       UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0             0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1             1            LIBRARY ASSISTANT                        Library
# 2             2               POLICE OFFICER  Houston Police Department-HPD
# 3             3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4             4                  ELECTRICIAN    General Services Department
# ...         ...                          ...                            ...
# 1995       1995               POLICE OFFICER  Houston Police Department-HPD
# 1996       1996       COMMUNICATIONS CAPTAIN  Houston Fire Department (HFD)
# 1997       1997               POLICE OFFICER  Houston Police Department-HPD
# 1998       1998               POLICE OFFICER  Houston Police Department-HPD
# 1999       1999                 FIRE FIGHTER  Houston Fire Department (HFD)
#
#       BASE_SALARY                       RACE EMPLOYMENT_TYPE  GENDER  \
# 0        121862.0            Hispanic/Latino       Full Time  Female
# 1         26125.0            Hispanic/Latino       Full Time  Female
# 2         45279.0                      White       Full Time    Male
# 3         63166.0                      White       Full Time    Male
# 4         56347.0                      White       Full Time    Male
# ...           ...                        ...             ...     ...
# 1995      43443.0                      White       Full Time    Male
# 1996      66523.0  Black or African American       Full Time    Male
# 1997      43443.0                      White       Full Time    Male
# 1998      55461.0     Asian/Pacific Islander       Full Time    Male
# 1999      51194.0            Hispanic/Latino       Full Time    Male
#
#      EMPLOYMENT_STATUS   HIRE_DATE    JOB_DATE  max_sal
# 0               Active  2006-06-12  2012-10-13      NaN
# 1               Active  2000-07-19  2010-09-18      NaN
# 2               Active  2015-02-03  2015-02-03      NaN
# 3               Active  1982-02-08  1991-05-25      NaN
# 4               Active  1989-06-19  1994-10-22      NaN
# ...                ...         ...         ...      ...
# 1995            Active  2014-06-09  2015-06-09      NaN
# 1996            Active  2003-09-02  2013-10-06      NaN
# 1997            Active  2014-10-13  2015-10-13      NaN
# 1998            Active  2009-01-20  2011-07-02      NaN
# 1999            Active  2009-01-12  2010-07-12      NaN
#
# [2000 rows x 11 columns]

# %%
(
    emp.merge(
    max_sal.rename('MAX_DEPT_SALARY'),
    how='left', 
    left_on='DEPARTMENT', #leftON은 저컬럼을 가지고 붙이겠어 !
    right_index=True#right도 인덱스로 되어있는지 !
    )
)
# Out:
#       UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0             0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1             1            LIBRARY ASSISTANT                        Library
# 2             2               POLICE OFFICER  Houston Police Department-HPD
# 3             3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4             4                  ELECTRICIAN    General Services Department
# ...         ...                          ...                            ...
# 1995       1995               POLICE OFFICER  Houston Police Department-HPD
# 1996       1996       COMMUNICATIONS CAPTAIN  Houston Fire Department (HFD)
# 1997       1997               POLICE OFFICER  Houston Police Department-HPD
# 1998       1998               POLICE OFFICER  Houston Police Department-HPD
# 1999       1999                 FIRE FIGHTER  Houston Fire Department (HFD)
#
#       BASE_SALARY                       RACE EMPLOYMENT_TYPE  GENDER  \
# 0        121862.0            Hispanic/Latino       Full Time  Female
# 1         26125.0            Hispanic/Latino       Full Time  Female
# 2         45279.0                      White       Full Time    Male
# 3         63166.0                      White       Full Time    Male
# 4         56347.0                      White       Full Time    Male
# ...           ...                        ...             ...     ...
# 1995      43443.0                      White       Full Time    Male
# 1996      66523.0  Black or African American       Full Time    Male
# 1997      43443.0                      White       Full Time    Male
# 1998      55461.0     Asian/Pacific Islander       Full Time    Male
# 1999      51194.0            Hispanic/Latino       Full Time    Male
#
#      EMPLOYMENT_STATUS   HIRE_DATE    JOB_DATE  MAX_DEPT_SALARY
# 0               Active  2006-06-12  2012-10-13         121862.0
# 1               Active  2000-07-19  2010-09-18         107763.0
# 2               Active  2015-02-03  2015-02-03         199596.0
# 3               Active  1982-02-08  1991-05-25         210588.0
# 4               Active  1989-06-19  1994-10-22          89194.0
# ...                ...         ...         ...              ...
# 1995            Active  2014-06-09  2015-06-09         199596.0
# 1996            Active  2003-09-02  2013-10-06         210588.0
# 1997            Active  2014-10-13  2015-10-13         199596.0
# 1998            Active  2009-01-20  2011-07-02         199596.0
# 1999            Active  2009-01-12  2010-07-12         210588.0
#
# [2000 rows x 11 columns]

# %%
college=pd.read_csv('data/college.csv',index_col='INSTNM')

# %%
college.dtypes
# Out:
# CITY                   object
# STABBR                 object
# HBCU                  float64
# MENONLY               float64
# WOMENONLY             float64
# RELAFFIL                int64
# SATVRMID              float64
# SATMTMID              float64
# DISTANCEONLY          float64
# UGDS                  float64
# UGDS_WHITE            float64
# UGDS_BLACK            float64
# UGDS_HISP             float64
# UGDS_ASIAN            float64
# UGDS_AIAN             float64
# UGDS_NHPI             float64
# UGDS_2MOR             float64
# UGDS_NRA              float64
# UGDS_UNKN             float64
# PPTUG_EF              float64
# CURROPER                int64
# PCTPELL               float64
# PCTFLOAN              float64
# UG25ABV               float64
# MD_EARN_WNE_P10        object
# GRAD_DEBT_MDN_SUPP     object
# dtype: object

# %% [markdown]
# object로 되어있는것은 왜일까
# 학생들의 프라이버시가 우려되기 때문에 제공하지 않는 것입니다.

# %%
college.MD_EARN_WNE_P10.value_counts().head()
# Out:
# PrivacySuppressed    822
# 38800                151
# 21500                 97
# 49200                 78
# 27400                 46
# Name: MD_EARN_WNE_P10, dtype: int64

# %% [markdown]
# 프라비어시때문에 지워진(가려진)데이터들이 문자형으로 들어있어 object로 되어있습니다.
# pandas 에서는 to_numeric을 통해 수치형 변수로 변결할 수 있습니다.
# 이때  errors='coerce'로 바꿔주면 수치형이 아닌 값을 NaN으로 만들어 줍니다.

# %%
cols=['MD_EARN_WNE_P10','GRAD_DEBT_MDN_SUPP']

for col in cols:
    college[col]=pd.to_numeric(
        college[col],errors='coerce'
    )

college.loc[:,cols].dtypes
# Out:
# MD_EARN_WNE_P10       float64
# GRAD_DEBT_MDN_SUPP    float64
# dtype: object

# %%
college_n=college.select_dtypes('number')
college_n.head()
# Out:
#                                      HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# INSTNM
# Alabama A & M University              1.0      0.0        0.0         0
# University of Alabama at Birmingham   0.0      0.0        0.0         0
# Amridge University                    0.0      0.0        0.0         1
# University of Alabama in Huntsville   0.0      0.0        0.0         0
# Alabama State University              1.0      0.0        0.0         0
#
#                                      SATVRMID  SATMTMID  DISTANCEONLY  \
# INSTNM
# Alabama A & M University                424.0     420.0           0.0
# University of Alabama at Birmingham     570.0     565.0           0.0
# Amridge University                        NaN       NaN           1.0
# University of Alabama in Huntsville     595.0     590.0           0.0
# Alabama State University                425.0     430.0           0.0
#
#                                         UGDS  UGDS_WHITE  UGDS_BLACK  ...  \
# INSTNM                                                                ...
# Alabama A & M University              4206.0      0.0333      0.9353  ...
# University of Alabama at Birmingham  11383.0      0.5922      0.2600  ...
# Amridge University                     291.0      0.2990      0.4192  ...
# University of Alabama in Huntsville   5451.0      0.6988      0.1255  ...
# Alabama State University              4811.0      0.0158      0.9208  ...
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  \
# INSTNM
# Alabama A & M University                0.0000    0.0059     0.0138    0.0656
# University of Alabama at Birmingham     0.0368    0.0179     0.0100    0.2607
# Amridge University                      0.0000    0.0000     0.2715    0.4536
# University of Alabama in Huntsville     0.0172    0.0332     0.0350    0.2146
# Alabama State University                0.0098    0.0243     0.0137    0.0892
#
#                                      CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# Alabama A & M University                    1   0.7356    0.8284   0.1049
# University of Alabama at Birmingham         1   0.3460    0.5214   0.2422
# Amridge University                          1   0.6801    0.7795   0.8540
# University of Alabama in Huntsville         1   0.3072    0.4596   0.2640
# Alabama State University                    1   0.7347    0.7554   0.1270
#
#                                      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                     30300.0             33888.0
# University of Alabama at Birmingham          39700.0             21941.5
# Amridge University                           40100.0             23370.0
# University of Alabama in Huntsville          45500.0             24097.0
# Alabama State University                     26600.0             33118.5
#
# [5 rows x 24 columns]

# %%
college.loc[:,cols]
# Out:
#                                                     MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University                                    30300.0
# University of Alabama at Birmingham                         39700.0
# Amridge University                                          40100.0
# University of Alabama in Huntsville                         45500.0
# Alabama State University                                    26600.0
# ...                                                             ...
# SAE Institute of Technology  San Francisco                      NaN
# Rasmussen College - Overland Park                               NaN
# National Personal Training Institute of Cleveland               NaN
# Bay Area Medical Academy - San Jose Satellite L...              NaN
# Excel Learning Center-San Antonio South                         NaN
#
#                                                     GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                                       33888.0
# University of Alabama at Birmingham                            21941.5
# Amridge University                                             23370.0
# University of Alabama in Huntsville                            24097.0
# Alabama State University                                       33118.5
# ...                                                                ...
# SAE Institute of Technology  San Francisco                      9500.0
# Rasmussen College - Overland Park                              21163.0
# National Personal Training Institute of Cleveland               6333.0
# Bay Area Medical Academy - San Jose Satellite L...                 NaN
# Excel Learning Center-San Antonio South                        12125.0
#
# [7535 rows x 2 columns]

# %%
#select_dtypes를 이용해 수치열만 보겠습니다.

# %%
college_n=college.select_dtypes('number')
college_n.head()
# Out:
#                                      HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# INSTNM
# Alabama A & M University              1.0      0.0        0.0         0
# University of Alabama at Birmingham   0.0      0.0        0.0         0
# Amridge University                    0.0      0.0        0.0         1
# University of Alabama in Huntsville   0.0      0.0        0.0         0
# Alabama State University              1.0      0.0        0.0         0
#
#                                      SATVRMID  SATMTMID  DISTANCEONLY  \
# INSTNM
# Alabama A & M University                424.0     420.0           0.0
# University of Alabama at Birmingham     570.0     565.0           0.0
# Amridge University                        NaN       NaN           1.0
# University of Alabama in Huntsville     595.0     590.0           0.0
# Alabama State University                425.0     430.0           0.0
#
#                                         UGDS  UGDS_WHITE  UGDS_BLACK  ...  \
# INSTNM                                                                ...
# Alabama A & M University              4206.0      0.0333      0.9353  ...
# University of Alabama at Birmingham  11383.0      0.5922      0.2600  ...
# Amridge University                     291.0      0.2990      0.4192  ...
# University of Alabama in Huntsville   5451.0      0.6988      0.1255  ...
# Alabama State University              4811.0      0.0158      0.9208  ...
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  \
# INSTNM
# Alabama A & M University                0.0000    0.0059     0.0138    0.0656
# University of Alabama at Birmingham     0.0368    0.0179     0.0100    0.2607
# Amridge University                      0.0000    0.0000     0.2715    0.4536
# University of Alabama in Huntsville     0.0172    0.0332     0.0350    0.2146
# Alabama State University                0.0098    0.0243     0.0137    0.0892
#
#                                      CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# Alabama A & M University                    1   0.7356    0.8284   0.1049
# University of Alabama at Birmingham         1   0.3460    0.5214   0.2422
# Amridge University                          1   0.6801    0.7795   0.8540
# University of Alabama in Huntsville         1   0.3072    0.4596   0.2640
# Alabama State University                    1   0.7347    0.7554   0.1270
#
#                                      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                     30300.0             33888.0
# University of Alabama at Birmingham          39700.0             21941.5
# Amridge University                           40100.0             23370.0
# University of Alabama in Huntsville          45500.0             24097.0
# Alabama State University                     26600.0             33118.5
#
# [5 rows x 24 columns]

# %%
#이 중에서 binary(0/1로 값이 구성된 것)을 찾아서 빼주겠습니다.  

is_binary=college_n.nunique()==2
is_binary.head()
# Out:
# HBCU          True
# MENONLY       True
# WOMENONLY     True
# RELAFFIL      True
# SATVRMID     False
# dtype: bool

# %% [markdown]
# 바이너리 최대값을 찾는것은 의미가 없으므로, unique가 2와 같으면 이 컬럼이 고유한값이 두가지니까 굳이 숫자로 만들지않아도 true false로 해도 되지

# %%
binary_cols=college_n.columns[is_binary]

# %%
is_binary.sum()
# Out:
# 6

# %%
binary_cols
# Out:
# Index(['HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL', 'DISTANCEONLY', 'CURROPER'], dtype='object')

# %% [markdown]
# 이제 binary_cols만 빼고 ! 선택하겠습니다.
# 아래 말고도 다른 방법이 있습니다.
# college_n.drop(columns=binary_cols)
# idxmax는 최대값이 되는 index를 찾아서 알려줍니다.
# 매우 유용하니 잘 기억해둡니다!
# idxmin도 있어요!

# %%
college_n2=college_n.loc[:,~is_binary]

# %%
[c for c in college_n.columns if c not in binary_cols]
# Out:
# ['SATVRMID',
#  'SATMTMID',
#  'UGDS',
#  'UGDS_WHITE',
#  'UGDS_BLACK',
#  'UGDS_HISP',
#  'UGDS_ASIAN',
#  'UGDS_AIAN',
#  'UGDS_NHPI',
#  'UGDS_2MOR',
#  'UGDS_NRA',
#  'UGDS_UNKN',
#  'PPTUG_EF',
#  'PCTPELL',
#  'PCTFLOAN',
#  'UG25ABV',
#  'MD_EARN_WNE_P10',
#  'GRAD_DEBT_MDN_SUPP']

# %%
college_n[binary_cols]
# Out:
#                                                     HBCU  MENONLY  WOMENONLY  \
# INSTNM
# Alabama A & M University                             1.0      0.0        0.0
# University of Alabama at Birmingham                  0.0      0.0        0.0
# Amridge University                                   0.0      0.0        0.0
# University of Alabama in Huntsville                  0.0      0.0        0.0
# Alabama State University                             1.0      0.0        0.0
# ...                                                  ...      ...        ...
# SAE Institute of Technology  San Francisco           NaN      NaN        NaN
# Rasmussen College - Overland Park                    NaN      NaN        NaN
# National Personal Training Institute of Cleveland    NaN      NaN        NaN
# Bay Area Medical Academy - San Jose Satellite L...   NaN      NaN        NaN
# Excel Learning Center-San Antonio South              NaN      NaN        NaN
#
#                                                     RELAFFIL  DISTANCEONLY  \
# INSTNM
# Alabama A & M University                                   0           0.0
# University of Alabama at Birmingham                        0           0.0
# Amridge University                                         1           1.0
# University of Alabama in Huntsville                        0           0.0
# Alabama State University                                   0           0.0
# ...                                                      ...           ...
# SAE Institute of Technology  San Francisco                 1           NaN
# Rasmussen College - Overland Park                          1           NaN
# National Personal Training Institute of Cleveland          1           NaN
# Bay Area Medical Academy - San Jose Satellite L...         1           NaN
# Excel Learning Center-San Antonio South                    1           NaN
#
#                                                     CURROPER
# INSTNM
# Alabama A & M University                                   1
# University of Alabama at Birmingham                        1
# Amridge University                                         1
# University of Alabama in Huntsville                        1
# Alabama State University                                   1
# ...                                                      ...
# SAE Institute of Technology  San Francisco                 1
# Rasmussen College - Overland Park                          1
# National Personal Training Institute of Cleveland          1
# Bay Area Medical Academy - San Jose Satellite L...         1
# Excel Learning Center-San Antonio South                    1
#
# [7535 rows x 6 columns]

# %%
college_n2
# Out:
#                                                     SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                               424.0     420.0
# University of Alabama at Birmingham                    570.0     565.0
# Amridge University                                       NaN       NaN
# University of Alabama in Huntsville                    595.0     590.0
# Alabama State University                               425.0     430.0
# ...                                                      ...       ...
# SAE Institute of Technology  San Francisco               NaN       NaN
# Rasmussen College - Overland Park                        NaN       NaN
# National Personal Training Institute of Cleveland        NaN       NaN
# Bay Area Medical Academy - San Jose Satellite L...       NaN       NaN
# Excel Learning Center-San Antonio South                  NaN       NaN
#
#                                                        UGDS  UGDS_WHITE  \
# INSTNM
# Alabama A & M University                             4206.0      0.0333
# University of Alabama at Birmingham                 11383.0      0.5922
# Amridge University                                    291.0      0.2990
# University of Alabama in Huntsville                  5451.0      0.6988
# Alabama State University                             4811.0      0.0158
# ...                                                     ...         ...
# SAE Institute of Technology  San Francisco              NaN         NaN
# Rasmussen College - Overland Park                       NaN         NaN
# National Personal Training Institute of Cleveland       NaN         NaN
# Bay Area Medical Academy - San Jose Satellite L...      NaN         NaN
# Excel Learning Center-San Antonio South                 NaN         NaN
#
#                                                     UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                                0.9353     0.0055
# University of Alabama at Birmingham                     0.2600     0.0283
# Amridge University                                      0.4192     0.0069
# University of Alabama in Huntsville                     0.1255     0.0382
# Alabama State University                                0.9208     0.0121
# ...                                                        ...        ...
# SAE Institute of Technology  San Francisco                 NaN        NaN
# Rasmussen College - Overland Park                          NaN        NaN
# National Personal Training Institute of Cleveland          NaN        NaN
# Bay Area Medical Academy - San Jose Satellite L...         NaN        NaN
# Excel Learning Center-San Antonio South                    NaN        NaN
#
#                                                     UGDS_ASIAN  UGDS_AIAN  \
# INSTNM
# Alabama A & M University                                0.0019     0.0024
# University of Alabama at Birmingham                     0.0518     0.0022
# Amridge University                                      0.0034     0.0000
# University of Alabama in Huntsville                     0.0376     0.0143
# Alabama State University                                0.0019     0.0010
# ...                                                        ...        ...
# SAE Institute of Technology  San Francisco                 NaN        NaN
# Rasmussen College - Overland Park                          NaN        NaN
# National Personal Training Institute of Cleveland          NaN        NaN
# Bay Area Medical Academy - San Jose Satellite L...         NaN        NaN
# Excel Learning Center-San Antonio South                    NaN        NaN
#
#                                                     UGDS_NHPI  UGDS_2MOR  \
# INSTNM
# Alabama A & M University                               0.0019     0.0000
# University of Alabama at Birmingham                    0.0007     0.0368
# Amridge University                                     0.0000     0.0000
# University of Alabama in Huntsville                    0.0002     0.0172
# Alabama State University                               0.0006     0.0098
# ...                                                       ...        ...
# SAE Institute of Technology  San Francisco                NaN        NaN
# Rasmussen College - Overland Park                         NaN        NaN
# National Personal Training Institute of Cleveland         NaN        NaN
# Bay Area Medical Academy - San Jose Satellite L...        NaN        NaN
# Excel Learning Center-San Antonio South                   NaN        NaN
#
#                                                     UGDS_NRA  UGDS_UNKN  \
# INSTNM
# Alabama A & M University                              0.0059     0.0138
# University of Alabama at Birmingham                   0.0179     0.0100
# Amridge University                                    0.0000     0.2715
# University of Alabama in Huntsville                   0.0332     0.0350
# Alabama State University                              0.0243     0.0137
# ...                                                      ...        ...
# SAE Institute of Technology  San Francisco               NaN        NaN
# Rasmussen College - Overland Park                        NaN        NaN
# National Personal Training Institute of Cleveland        NaN        NaN
# Bay Area Medical Academy - San Jose Satellite L...       NaN        NaN
# Excel Learning Center-San Antonio South                  NaN        NaN
#
#                                                     PPTUG_EF  PCTPELL  \
# INSTNM
# Alabama A & M University                              0.0656   0.7356
# University of Alabama at Birmingham                   0.2607   0.3460
# Amridge University                                    0.4536   0.6801
# University of Alabama in Huntsville                   0.2146   0.3072
# Alabama State University                              0.0892   0.7347
# ...                                                      ...      ...
# SAE Institute of Technology  San Francisco               NaN      NaN
# Rasmussen College - Overland Park                        NaN      NaN
# National Personal Training Institute of Cleveland        NaN      NaN
# Bay Area Medical Academy - San Jose Satellite L...       NaN      NaN
# Excel Learning Center-San Antonio South                  NaN      NaN
#
#                                                     PCTFLOAN  UG25ABV  \
# INSTNM
# Alabama A & M University                              0.8284   0.1049
# University of Alabama at Birmingham                   0.5214   0.2422
# Amridge University                                    0.7795   0.8540
# University of Alabama in Huntsville                   0.4596   0.2640
# Alabama State University                              0.7554   0.1270
# ...                                                      ...      ...
# SAE Institute of Technology  San Francisco               NaN      NaN
# Rasmussen College - Overland Park                        NaN      NaN
# National Personal Training Institute of Cleveland        NaN      NaN
# Bay Area Medical Academy - San Jose Satellite L...       NaN      NaN
# Excel Learning Center-San Antonio South                  NaN      NaN
#
#                                                     MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University                                    30300.0
# University of Alabama at Birmingham                         39700.0
# Amridge University                                          40100.0
# University of Alabama in Huntsville                         45500.0
# Alabama State University                                    26600.0
# ...                                                             ...
# SAE Institute of Technology  San Francisco                      NaN
# Rasmussen College - Overland Park                               NaN
# National Personal Training Institute of Cleveland               NaN
# Bay Area Medical Academy - San Jose Satellite L...              NaN
# Excel Learning Center-San Antonio South                         NaN
#
#                                                     GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                                       33888.0
# University of Alabama at Birmingham                            21941.5
# Amridge University                                             23370.0
# University of Alabama in Huntsville                            24097.0
# Alabama State University                                       33118.5
# ...                                                                ...
# SAE Institute of Technology  San Francisco                      9500.0
# Rasmussen College - Overland Park                              21163.0
# National Personal Training Institute of Cleveland               6333.0
# Bay Area Medical Academy - San Jose Satellite L...                 NaN
# Excel Learning Center-San Antonio South                        12125.0
#
# [7535 rows x 18 columns]

# %% [markdown]
# 이 방법도 있죠! binary인건 drop!

# %%
college_n.drop(columns=binary_cols)
# Out:
#                                                     SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                               424.0     420.0
# University of Alabama at Birmingham                    570.0     565.0
# Amridge University                                       NaN       NaN
# University of Alabama in Huntsville                    595.0     590.0
# Alabama State University                               425.0     430.0
# ...                                                      ...       ...
# SAE Institute of Technology  San Francisco               NaN       NaN
# Rasmussen College - Overland Park                        NaN       NaN
# National Personal Training Institute of Cleveland        NaN       NaN
# Bay Area Medical Academy - San Jose Satellite L...       NaN       NaN
# Excel Learning Center-San Antonio South                  NaN       NaN
#
#                                                        UGDS  UGDS_WHITE  \
# INSTNM
# Alabama A & M University                             4206.0      0.0333
# University of Alabama at Birmingham                 11383.0      0.5922
# Amridge University                                    291.0      0.2990
# University of Alabama in Huntsville                  5451.0      0.6988
# Alabama State University                             4811.0      0.0158
# ...                                                     ...         ...
# SAE Institute of Technology  San Francisco              NaN         NaN
# Rasmussen College - Overland Park                       NaN         NaN
# National Personal Training Institute of Cleveland       NaN         NaN
# Bay Area Medical Academy - San Jose Satellite L...      NaN         NaN
# Excel Learning Center-San Antonio South                 NaN         NaN
#
#                                                     UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                                0.9353     0.0055
# University of Alabama at Birmingham                     0.2600     0.0283
# Amridge University                                      0.4192     0.0069
# University of Alabama in Huntsville                     0.1255     0.0382
# Alabama State University                                0.9208     0.0121
# ...                                                        ...        ...
# SAE Institute of Technology  San Francisco                 NaN        NaN
# Rasmussen College - Overland Park                          NaN        NaN
# National Personal Training Institute of Cleveland          NaN        NaN
# Bay Area Medical Academy - San Jose Satellite L...         NaN        NaN
# Excel Learning Center-San Antonio South                    NaN        NaN
#
#                                                     UGDS_ASIAN  UGDS_AIAN  \
# INSTNM
# Alabama A & M University                                0.0019     0.0024
# University of Alabama at Birmingham                     0.0518     0.0022
# Amridge University                                      0.0034     0.0000
# University of Alabama in Huntsville                     0.0376     0.0143
# Alabama State University                                0.0019     0.0010
# ...                                                        ...        ...
# SAE Institute of Technology  San Francisco                 NaN        NaN
# Rasmussen College - Overland Park                          NaN        NaN
# National Personal Training Institute of Cleveland          NaN        NaN
# Bay Area Medical Academy - San Jose Satellite L...         NaN        NaN
# Excel Learning Center-San Antonio South                    NaN        NaN
#
#                                                     UGDS_NHPI  UGDS_2MOR  \
# INSTNM
# Alabama A & M University                               0.0019     0.0000
# University of Alabama at Birmingham                    0.0007     0.0368
# Amridge University                                     0.0000     0.0000
# University of Alabama in Huntsville                    0.0002     0.0172
# Alabama State University                               0.0006     0.0098
# ...                                                       ...        ...
# SAE Institute of Technology  San Francisco                NaN        NaN
# Rasmussen College - Overland Park                         NaN        NaN
# National Personal Training Institute of Cleveland         NaN        NaN
# Bay Area Medical Academy - San Jose Satellite L...        NaN        NaN
# Excel Learning Center-San Antonio South                   NaN        NaN
#
#                                                     UGDS_NRA  UGDS_UNKN  \
# INSTNM
# Alabama A & M University                              0.0059     0.0138
# University of Alabama at Birmingham                   0.0179     0.0100
# Amridge University                                    0.0000     0.2715
# University of Alabama in Huntsville                   0.0332     0.0350
# Alabama State University                              0.0243     0.0137
# ...                                                      ...        ...
# SAE Institute of Technology  San Francisco               NaN        NaN
# Rasmussen College - Overland Park                        NaN        NaN
# National Personal Training Institute of Cleveland        NaN        NaN
# Bay Area Medical Academy - San Jose Satellite L...       NaN        NaN
# Excel Learning Center-San Antonio South                  NaN        NaN
#
#                                                     PPTUG_EF  PCTPELL  \
# INSTNM
# Alabama A & M University                              0.0656   0.7356
# University of Alabama at Birmingham                   0.2607   0.3460
# Amridge University                                    0.4536   0.6801
# University of Alabama in Huntsville                   0.2146   0.3072
# Alabama State University                              0.0892   0.7347
# ...                                                      ...      ...
# SAE Institute of Technology  San Francisco               NaN      NaN
# Rasmussen College - Overland Park                        NaN      NaN
# National Personal Training Institute of Cleveland        NaN      NaN
# Bay Area Medical Academy - San Jose Satellite L...       NaN      NaN
# Excel Learning Center-San Antonio South                  NaN      NaN
#
#                                                     PCTFLOAN  UG25ABV  \
# INSTNM
# Alabama A & M University                              0.8284   0.1049
# University of Alabama at Birmingham                   0.5214   0.2422
# Amridge University                                    0.7795   0.8540
# University of Alabama in Huntsville                   0.4596   0.2640
# Alabama State University                              0.7554   0.1270
# ...                                                      ...      ...
# SAE Institute of Technology  San Francisco               NaN      NaN
# Rasmussen College - Overland Park                        NaN      NaN
# National Personal Training Institute of Cleveland        NaN      NaN
# Bay Area Medical Academy - San Jose Satellite L...       NaN      NaN
# Excel Learning Center-San Antonio South                  NaN      NaN
#
#                                                     MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University                                    30300.0
# University of Alabama at Birmingham                         39700.0
# Amridge University                                          40100.0
# University of Alabama in Huntsville                         45500.0
# Alabama State University                                    26600.0
# ...                                                             ...
# SAE Institute of Technology  San Francisco                      NaN
# Rasmussen College - Overland Park                               NaN
# National Personal Training Institute of Cleveland               NaN
# Bay Area Medical Academy - San Jose Satellite L...              NaN
# Excel Learning Center-San Antonio South                         NaN
#
#                                                     GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                                       33888.0
# University of Alabama at Birmingham                            21941.5
# Amridge University                                             23370.0
# University of Alabama in Huntsville                            24097.0
# Alabama State University                                       33118.5
# ...                                                                ...
# SAE Institute of Technology  San Francisco                      9500.0
# Rasmussen College - Overland Park                              21163.0
# National Personal Training Institute of Cleveland               6333.0
# Bay Area Medical Academy - San Jose Satellite L...                 NaN
# Excel Learning Center-San Antonio South                        12125.0
#
# [7535 rows x 18 columns]

# %% [markdown]
# 인덱스의 맥스를 해줍니다. 각 컬럼별로 1등을 뽑아줍니다. 이 최대값을 찾아서 인덱스가 뭔지를 보여주는게 idxmax가 됩니다. 그러니까 지금 여기서는 쉽게생각해서 올림픽 금메달딴사람들만 모아준것이죠. unique를 하게되면 중복되는거 없이 나오게 됩니다.

# %%
max_cols=college_n2.idxmax()

# %%
max_cols
# Out:
# SATVRMID                             California Institute of Technology
# SATMTMID                             California Institute of Technology
# UGDS                                      University of Phoenix-Arizona
# UGDS_WHITE                       Mr Leon's School of Hair Design-Moscow
# UGDS_BLACK                           Velvatex College of Beauty Culture
# UGDS_HISP                       Thunderbird School of Global Management
# UGDS_ASIAN                          Cosmopolitan Beauty and Tech School
# UGDS_AIAN                             Haskell Indian Nations University
# UGDS_NHPI                                       Palau Community College
# UGDS_2MOR                                                 LIU Brentwood
# UGDS_NRA               California University of Management and Sciences
# UGDS_UNKN             Le Cordon Bleu College of Culinary Arts-San Fr...
# PPTUG_EF                        Thunderbird School of Global Management
# PCTPELL                                        MTI Business College Inc
# PCTFLOAN                                         ABC Beauty College Inc
# UG25ABV                                  Dongguk University-Los Angeles
# MD_EARN_WNE_P10                            Medical College of Wisconsin
# GRAD_DEBT_MDN_SUPP           Southwest University of Visual Arts-Tucson
# dtype: object

# %%
unique_max_cols=max_cols.unique()
unique_max_cols
# Out:
# array(['California Institute of Technology',
#        'University of Phoenix-Arizona',
#        "Mr Leon's School of Hair Design-Moscow",
#        'Velvatex College of Beauty Culture',
#        'Thunderbird School of Global Management',
#        'Cosmopolitan Beauty and Tech School',
#        'Haskell Indian Nations University', 'Palau Community College',
#        'LIU Brentwood',
#        'California University of Management and Sciences',
#        'Le Cordon Bleu College of Culinary Arts-San Francisco',
#        'MTI Business College Inc', 'ABC Beauty College Inc',
#        'Dongguk University-Los Angeles', 'Medical College of Wisconsin',
#        'Southwest University of Visual Arts-Tucson'], dtype=object)

# %%
college_n2.loc[unique_max_cols].style.highlight_max(axis='index')
# Out:
# <style  type="text/css" >
# #T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col0,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col1,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col2,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row2_col3,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row3_col4,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row4_col5,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row4_col12,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row5_col6,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row6_col7,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row7_col8,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row8_col9,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row9_col10,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row10_col11,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row11_col13,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row11_col14,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row12_col14,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row13_col15,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row14_col16,#T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row15_col17{
#             background-color:  yellow;
#         }</style><table id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SATVRMID</th>        <th class="col_heading level0 col1" >SATMTMID</th>        <th class="col_heading level0 col2" >UGDS</th>        <th class="col_heading level0 col3" >UGDS_WHITE</th>        <th class="col_heading level0 col4" >UGDS_BLACK</th>        <th class="col_heading level0 col5" >UGDS_HISP</th>        <th class="col_heading level0 col6" >UGDS_ASIAN</th>        <th class="col_heading level0 col7" >UGDS_AIAN</th>        <th class="col_heading level0 col8" >UGDS_NHPI</th>        <th class="col_heading level0 col9" >UGDS_2MOR</th>        <th class="col_heading level0 col10" >UGDS_NRA</th>        <th class="col_heading level0 col11" >UGDS_UNKN</th>        <th class="col_heading level0 col12" >PPTUG_EF</th>        <th class="col_heading level0 col13" >PCTPELL</th>        <th class="col_heading level0 col14" >PCTFLOAN</th>        <th class="col_heading level0 col15" >UG25ABV</th>        <th class="col_heading level0 col16" >MD_EARN_WNE_P10</th>        <th class="col_heading level0 col17" >GRAD_DEBT_MDN_SUPP</th>    </tr>    <tr>        <th class="index_name level0" >INSTNM</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62level0_row0" class="row_heading level0 row0" >California Institute of Technology</th>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col0" class="data row0 col0" >765.000000</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col1" class="data row0 col1" >785.000000</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col2" class="data row0 col2" >983.000000</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col3" class="data row0 col3" >0.278700</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col4" class="data row0 col4" >0.015300</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col5" class="data row0 col5" >0.122100</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col6" class="data row0 col6" >0.438500</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col7" class="data row0 col7" >0.001000</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col8" class="data row0 col8" >0.000000</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col9" class="data row0 col9" >0.057000</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col10" class="data row0 col10" >0.087500</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col11" class="data row0 col11" >0.000000</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col12" class="data row0 col12" >0.000000</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col13" class="data row0 col13" >0.112600</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col14" class="data row0 col14" >0.230300</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col15" class="data row0 col15" >0.008200</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col16" class="data row0 col16" >77800.000000</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row0_col17" class="data row0 col17" >11812.500000</td>
#             </tr>
#             <tr>
#                         <th id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62level0_row1" class="row_heading level0 row1" >University of Phoenix-Arizona</th>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col1" class="data row1 col1" >nan</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col2" class="data row1 col2" >151558.000000</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col3" class="data row1 col3" >0.309800</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col4" class="data row1 col4" >0.155500</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col5" class="data row1 col5" >0.076000</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col6" class="data row1 col6" >0.008200</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col7" class="data row1 col7" >0.004200</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col8" class="data row1 col8" >0.005000</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col9" class="data row1 col9" >0.113100</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col10" class="data row1 col10" >0.013100</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col11" class="data row1 col11" >0.315200</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col12" class="data row1 col12" >0.000000</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col13" class="data row1 col13" >0.600900</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col14" class="data row1 col14" >0.592000</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col15" class="data row1 col15" >nan</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col16" class="data row1 col16" >nan</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row1_col17" class="data row1 col17" >33000.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62level0_row2" class="row_heading level0 row2" >Mr Leon's School of Hair Design-Moscow</th>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row2_col0" class="data row2 col0" >nan</td>
#                         <td id="T_e8e8e778_ab11_11eb_8aca_e864f0ea9c62row2_col1" class="data row2 col1" >nan</td>

# %% [markdown]
# 각 컬럼에서 최고값을 하이라이트로 볼 수 있습니다.

# %%
college.filter(like='UGDS')
