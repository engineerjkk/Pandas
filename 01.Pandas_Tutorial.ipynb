# %% [markdown]
# # 개요
# #### pandas의 기본적인 사항들에 대해 알아보겠습니다.
# #### pandas는 python의 대표적인 데이터 분석용 라이브러리 입니다. 이를 활용하여 데이터를 구조화하고 조작할 수 있습니다.
# #### 먼저 pandas를 불러오는데 보통 numpy와 함께 로드하며, 각각 pd와 np라는 별명을 주로 사용합니다..

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pandas DataFrame
# #### pandas는 DataFrame과 Series의 데이터 구조를 갖고 있다.
# #### DataFrame(DF)은 표 형태의 2차원 데이터 구조로, 행(인덱스), 열 그리고 데이터를 갖는다. Series는 1차원 데이터 구조로 인덱스와 데이터만을 갖는다.
# ![image.png](attachment:image.png)

# %% [markdown]
# # DF
# 데이터를 불러와서 DF를 만들어 본다.
# ## pd.read_csv
# 판다스에서 csv 파일을 읽어오는 함수
# ## type()
# 타입이 무엇인지 알고싶을 때 사용합니다. 현재 movies는 DataFrame입니다.

# %%
movies=pd.read_csv('movie.csv')
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# * movies에 read_csv 함수의 결과가 들어갔습니다.
# csv는 comma seperated values의 약자로, 쉼표로 구분한 데이터의 형태를 의미합니다.
# 쉽게 생각하면 엑셀의 내용만 저장한 형태가 되는 것입니다.
# * type으로 확인해보면 DataFrame인 것을 알수 있다. 즉, read_csv의 결과는 DF가 됩니다.
# * NaN은 Not a Number의 약자이다. 여기서 결측지(missing value)를 의미합니다.
# * _ 은 데이터가 생략되어 있음을 의미합니다
# 보통 데이터 전체를 출력하는 경우는 많지 않습니다.
# head나 tail 함수를 사용하는 방법은 아래와 같습니다
# - movies.head() #상위 5줄
# - movies.head(10) #상위 10줄

# %%
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movies.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4911  Color       Scott Smith                     1.0      87.0
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  ...  \
# ...

# %% [markdown]
# DF는 세 요소로 구성됩니다.
# ### 열,인덱스(행) 그리고 데이터
# 이를 각각 접근할 수 있습니다.
# # .columns
# 컬럼은 28개였기 때문에 index또한 28개가 출력됩니다.

# %%
columns = movies.columns
columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# 인덱스는 row의 번호이다.
# 0~4916번까지가 인덱스 번호임을 기억하자

# %%
index = movies.index

# %%
index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %% [markdown]
# # .to_numpy()
# 리스트 형태로 출력한다.

# %%
data=movies.to_numpy()
data
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %% [markdown]
# # 데이터 형식
# pandas의 데이터 형식은 다음과 같은 종류가 있습니다. 각 컬럼이 어떤 형식인지 정확이 아는것이 중요합니다. 결측치를 표시할 수 있는지 여부에 따라 달라집니다.
#
# - float : 부동소수점 (결측치O)
# - int : 정수 ( 결측치 X)
# - int64 : 정수 (결측치 O)
# - object : 문자열
# - category : 범주형 (결측치 O)
# - bool : 불리언 (결측치 X)
# - boolead : 불리언 (결측치 O)
# - datetime64 : 날짜 (결측치 O)
#
# movies의 컬럼들은 어떤 타입인지 볼까요?
# # DF.dtype
# ![image.png](attachment:image.png)
# 너무 길면 작은창으로 스크롤해 볼 수 있습니다.

# %%
movies.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %% [markdown]
# dtypes의 결과는 Series 이기 때문에, 값을 셀 수 있는 'value_counts' 함수를 사용할 수 있다.

# %%
movies.dtypes.value_counts()
# Out:
# float64    13
# object     12
# int64       3
# dtype: int64

# %% [markdown]
# # info()
# 데이터프레임에 적용가능한 함수인데, 값들이 들어가있는 것을 카운트 해준다.

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
# ...

# %% [markdown]
# # 열과 행의 선택
# DF는 표 형태이기 때문에 열 혹은 행을 기준으로 데이터를 선택할 수 있습니다.
# 기본적으로 numpy의 array을 선택하는 것과 동일하게 데이터를 있습니다.
# 'A'라는 열이 첫 열로 df에 있을때
# * df.A
# * df['A']
# * df.loc[:,'A'] #행에대해 : 을 놓으면 모든 행을 의미한다.
# * df.iloc[:,0] #0은 컬럼의 위치를 의미한다.
#
# 1번과 2번 방법은 직관적입니다.
# 3번 loc는 레이블 이름 기반으로 데이터에 접근을 합니다. 이름표를 보고 갑니다.
# 4번 iloc는 위치 기반으로 데이터에 접근을 합니다. 데이터의 위치번호를 보고 접근합니다.
# 그리고, 두 개의 차원을 표시할 때 :는 모든 것을 의미합니다. 즉, 모든 행을 선택하는데 열 이름이 'A'인 것입니다.
# movies의 director_name 칼럼에 접근해 보겠습니다.

# %%
movies.loc[:,'director_name']
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
movies.iloc[:,1]
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
type(movies.director_name)
# Out:
# pandas.core.series.Series

# %% [markdown]
# 여러 방법이 있지만 가장 타이핑이 적은 방법은 .을 쓰는 것입니다.
# 게다가 jupyterlab에서는 자동완성도 지원해주니 편합니다.
# 다만, 일부 특수어를 칼럼 이름으로 가진 경우나, 컬럼 이름에 빈칸이 있는 경우에는 반드시 df['A']를 사용해야 합니다.
# 또한 새로운 칼럼을 만들 때에도 .은 사용할 수 없습니다.
# 보통 간단한 Series를 추출할 때에 .을 사용합니다.

# %%
director=movies.director_name
fb_likes=movies.actor_1_facebook_likes

# %% [markdown]
# Series도 마찬가지로 너무 긴 경우 다 표현할 필요는 없습니다.
# head/tail을 사용할 수 있지만 여기서는 sample이란 함수를 사용해 보겠습니다.
# 말 그대로 sampling을 해주는 (몇개만 추출해주는) 함수입니다.
# * s.sample(n=?,random_state=?)
#
# n은 샘플링 할 개수를 의미하고, random_state는 random을 컨트롤하기 위해 넣는 숫자입니다. 아무리 랜덤이라도 동일한 숫자를 넣는다면 그 숫자에서는 동일한 랜덤값이 계속나오게 됩니다.

# %%
director.sample(3)
# Out:
# 4560    Catherine Jelski
# 2871          Paul Weitz
# 4129       George Sidney
# Name: director_name, dtype: object

# %%
director.sample(3,random_state=42)
# Out:
# 2347    Brian Percival
# 4687       Lucio Fulci
# 691      Phillip Noyce
# Name: director_name, dtype: object

# %% [markdown]
# # Value_counts 값의 개수 세기
# value_counts는 가장 자주 쓰는 함수 중 하나입니다.
# 말 그대로 값의 개수를 세어줍니다.
# 일반적으로는 명목형/factor 컬럼에 적용을 하구요.
# director에 적용시켜보겠습니다.
# 지금은 스티븐 스필버그가 26번 호출되었음을 알 수 있네요.

# %%
director.value_counts()
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Clint Eastwood      20
# Martin Scorsese     20
# Spike Lee           16
#                     ..
# James Kerwin         1
# Robert Heath         1
# Hue Rhodes           1
# David Hunt           1
# Hans Canosa          1
# Name: director_name, Length: 2397, dtype: int64

# %% [markdown]
# nomalize=True의 인자를 넘겨주게 되면 비율을 구해줄 수 있습니다.
# 스티븐스필버그는 0.5%정도의 비율을 차지하고 있군요

# %%
director.value_counts(normalize=True)
# Out:
# Steven Spielberg    0.005401
# Woody Allen         0.004570
# Clint Eastwood      0.004155
# Martin Scorsese     0.004155
# Spike Lee           0.003324
#                       ...
# James Kerwin        0.000208
# Robert Heath        0.000208
# Hue Rhodes          0.000208
# David Hunt          0.000208
# Hans Canosa         0.000208
# Name: director_name, Length: 2397, dtype: float64

# %% [markdown]
# # Describe : 기술 통계
# describe를 사용하면 수치형 데이터의 기술 통계를 구할 수 있습니다.
# df와 s 모두 적용이 가능합니다.
# 명목형 또는 string 칼럼에 대해서는 count와 unique,top 같이 나옵니다.

# %%
movies.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 25%                 49.000000    93.000000                 7.000000
# 50%                108.000000   103.000000                48.000000
# 75%                191.000000   118.000000               189.750000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
director.describe()
# Out:
# count                 4814
# unique                2397
# top       Steven Spielberg
# freq                    26
# Name: director_name, dtype: object

# %% [markdown]
# 만약 object타입의 컬럼들만 보고싶으면 아래와 같이 하면 됩니다.
# Object를 뜻하는 대문자 O를 써줍니다.

# %%
movies.describe(include=['O'])
# Out:
#         color     director_name    actor_2_name genres    actor_1_name  \
# count    4897              4814            4903   4916            4909
# unique      2              2397            3030    914            2095
# top     Color  Steven Spielberg  Morgan Freeman  Drama  Robert De Niro
# freq     4693                26              18    233              48
#
#           movie_title  actor_3_name   plot_keywords  \
# count            4916          4893            4764
# unique           4916          3519            4756
# top     Casino Royale  Steve Coogan  based on novel
# freq                1             8               4
#
#                                           movie_imdb_link language country  \
# count                                                4916     4904    4911
# unique                                               4916       47      65
# top     http://www.imdb.com/title/tt0253474/?ref_=fn_t...  English     USA
# ...

# %% [markdown]
# Row index로 동작하는 것의 대부분은 함수로 추출할 수 있습니다.
# 예를 들어 count, mean, std, min, max, unique와 같은 것들은 함수로 해당하는 값을 구할 수 있죠.

# %%
fb1=movies.actor_1_facebook_likes
print(fb1.min(),fb1.max(),fb1.mean())
# Out:
# 0.0 640000.0 6494.488490527602

# %% [markdown]
# NA값 확인하기 isna/fillna/dropna
# info에서 null이 아닌 값의 개수를 확인했었습니다.
# null의 수를 세는 또 다른 방법은 isna 함수를 사용하는 것입니다.
# isna는 na인 경우 True를, 그렇지 않은 경우 False를 리턴해줍니다.

# %%
test_series=pd.Series([1,3,6,np.nan,1])
test_series.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool

# %% [markdown]
# 결측치의 개수도 .sum()을 통해서 알 수 있습니다.

# %%
test_series=pd.Series([1,3,6,np.nan,1])
test_series.isna().sum()
# Out:
# 1

# %%
movies.isna().sum()
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %% [markdown]
# 결측치를 채울 때에는 fillna 함수를 사용합니다.
# # series.fillna(채울값)
# 의 형태로 사용할 수 있습니다.

# %%
test_series.fillna(0)
# Out:
# 0    1.0
# 1    3.0
# 2    6.0
# 3    0.0
# 4    1.0
# dtype: float64

# %% [markdown]
# 값을 채우는 것이 아닌, 결측치를 삭제하고 싶을 때에는 dropna를 사용합니다.

# %%
test_series.dropna()
# Out:
# 0    1.0
# 1    3.0
# 2    6.0
# 4    1.0
# dtype: float64

# %% [markdown]
# 그렇지만 dropna()는 영구적으로 삭제하는것이 아닙니다. 한번 확인해 볼까요?

# %%
test_series
# Out:
# 0    1.0
# 1    3.0
# 2    6.0
# 3    NaN
# 4    1.0
# dtype: float64

# %% [markdown]
# 따라서 영구적으로 바꾸기 위해서는 아래와 같은 방법이 있지만 데이터가 변경되면 되돌릴 수 없으니 조심하세요.
# # test_series=test_series.dropna()
# # test_series.dropna(inplace=True)

# %% [markdown]
# # Series의 연산
# series를 계산에 사용할 때에는 재미있는 특징이 있습니다.
# 실제고는 (1,2,3)+(1,1,1)이 되는 것입니다.

# %%
a=pd.Series([1,2,3])
a+1
# Out:
# 0    2
# 1    3
# 2    4
# dtype: int64

# %%
a=pd.Series(np.arange(0,10))
print(a%2==0)
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# 9    False
# dtype: bool

# %%
fb_likes.add(1)
fb_likes.sub(2)
# Out:
# 0         998.0
# 1       39998.0
# 2       10998.0
# 3       26998.0
# 4         129.0
#          ...
# 4911      635.0
# 4912      839.0
# 4913       -2.0
# 4914      944.0
# 4915       84.0
# Name: actor_1_facebook_likes, Length: 4916, dtype: float64

# %% [markdown]
# nan값은 어떤 사칙연산을 하더라도 nan값이 나옵니다.
# 하지만 fill_value 인자를 통해 처리할 수 있습니다.

# %%
np.nan-1
# Out:
# nan

# %% [markdown]
# 만약에 nan값이나오면 0으로 한다음에 2를 빼세요

# %%
fb_likes.sub(2,fill_value=0)[fb_likes.isna()]
# Out:
# 4401   -2.0
# 4418   -2.0
# 4608   -2.0
# 4721   -2.0
# 4822   -2.0
# 4823   -2.0
# 4864   -2.0
# Name: actor_1_facebook_likes, dtype: float64

# %% [markdown]
# # 메서드 체인
# pandas에서는 메서드의 결과에 다시 메서드를 적용할 수 있습니다.
# 이게 가능한 이유는 같은 series이기 때문이죠

# %%
director.value_counts().head()
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Clint Eastwood      20
# Martin Scorsese     20
# Spike Lee           16
# Name: director_name, dtype: int64

# %% [markdown]
# DF에서 열 다루고 이름을 바꾸어보죠
# 먼저 dictionary를 리뷰해보고 가볼게요.
# 앞의 인자가 Key, 뒤가 Value입니다. 그래서 일종의 사전의 형태를 띄게 되는거죠.
# columns를 col_map으로 바꾸고 모든 행과 그리고 0~2열까지중에서 상위 다섯개만 출력해 볼게요.

# %%
col_map={'director_name':'director','num_critic_for_reviews':'critic_reviews'}
movies.rename(columns=col_map).iloc[:,:3].head()
# Out:
#    color           director  critic_reviews
# 0  Color      James Cameron           723.0
# 1  Color     Gore Verbinski           302.0
# 2  Color         Sam Mendes           602.0
# 3  Color  Christopher Nolan           813.0
# 4    NaN        Doug Walker             NaN

# %% [markdown]
# 해당자리에는 딕셔너리 말고도 함수도 넣을 수 있습니다.
# 람다 함수를 사용해볼게요
# x의 인풋을 가지고 strip으로 빈칸을 정리해주고 upper로 대문자로 만들고 head로 5개만 가져 줍니다.

# %%
movies.rename(columns=lambda x : x.strip().upper()).head()
# Out:
#    COLOR      DIRECTOR_NAME  NUM_CRITIC_FOR_REVIEWS  DURATION  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES      ACTOR_2_NAME  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    ACTOR_1_FACEBOOK_LIKES        GROSS                           GENRES  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# # DF의 열 다루기. 열 생성과 삭제
# df['열이름']입니다.
# 예를 들어, movies에 새로운 열 A를 만든다고 가정해 볼게요.
# 그리고 초기값을 모두 0으로 초기화 한다면,

# %%
movies['A']=0
movies.A
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4911    0
# 4912    0
# 4913    0
# 4914    0
# 4915    0
# Name: A, Length: 4916, dtype: int64

# %%
movies.B=0 # 이런식으로는 열을 새로 만들 수 없습니다.

# %%
movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'A'],
#       dtype='object')

# %% [markdown]
# 새로운 열을 만들어 보겠습니다. 새로운 이름의 total_lieks를 만들고 actor1,2,3,director을 더해서 새로운 열을 채워볼게요

# %%
movies['total_likes']=(movies.actor_1_facebook_likes+
                      movies.actor_2_facebook_likes+
                      movies.actor_3_facebook_likes+
                      movies.director_facebook_likes)

# %%
movies.total_likes
# Out:
# 0        2791.0
# 1       46563.0
# 2       11554.0
# 3       95000.0
# 4           NaN
#          ...
# 4911     1427.0
# 4912        NaN
# 4913        0.0
# 4914     2154.0
# 4915      141.0
# Name: total_likes, Length: 4916, dtype: float64

# %% [markdown]
# 동일한 결과를 sum 함수를 이용하여서도 만들 수 있습니다.
# axis=1은 컬럼 방향으로의 합을 의미합니다.
# 기본값은 0이기에 1을 선택해줍시다. 우리는 각 영화들의 합을 원합니다.

# %%
cols=['actor_1_facebook_likes',
                      'actor_2_facebook_likes',
                      'actor_3_facebook_likes',
                      'director_facebook_likes']
sum_col=movies.loc[:,cols].sum(axis=1)
sum_col
# Out:
# 0        2791.0
# 1       46563.0
# 2       11554.0
# 3       95000.0
# 4         274.0
#          ...
# 4911     1427.0
# 4912     1753.0
# 4913        0.0
# 4914     2154.0
# 4915      141.0
# Length: 4916, dtype: float64

# %% [markdown]
# movies df는 상당히 크기 때문에, facebook 이 컬럼에 들어가 있는 것만 선택해서 새로운 df를 만들어 보겠습니다.
# movies df에 전체 컬럼이름 중에서 facebook이 들어가는지 확인하는 것입니다. 그럼 facebook 키워드가 있는 컬럼만 볼수 있는것입니다.

# %%
movies_fb=movies[[
    c
    for c in movies.columns
    if 'facebook' in c
]]

# %%
[
    c
    for c in movies.columns
    if 'facebook' in c
]
# Out:
# ['director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_1_facebook_likes',
#  'cast_total_facebook_likes',
#  'actor_2_facebook_likes',
#  'movie_facebook_likes']

# %%
movies_fb #6개의 컬럼만 선택한 결과를 본다.
# Out:
#       director_facebook_likes  actor_3_facebook_likes  actor_1_facebook_likes  \
# 0                         0.0                   855.0                  1000.0
# 1                       563.0                  1000.0                 40000.0
# 2                         0.0                   161.0                 11000.0
# 3                     22000.0                 23000.0                 27000.0
# 4                       131.0                     NaN                   131.0
# ...                       ...                     ...                     ...
# 4911                      2.0                   318.0                   637.0
# 4912                      NaN                   319.0                   841.0
# 4913                      0.0                     0.0                     0.0
# 4914                      0.0                   489.0                   946.0
# 4915                     16.0                    16.0                    86.0
#
# ...

# %% [markdown]
# 각 영화마다 facebook_likes의 총합을 구할 수 있다.

# %%
movies_fb.sum(axis=1)
# Out:
# 0        40625.0
# 1        94913.0
# 2       108254.0
# 3       365759.0
# 4          417.0
#           ...
# 4911      3794.0
# 4912     35506.0
# 4913        16.0
# 4914      5200.0
# 4915       760.0
# Length: 4916, dtype: float64

# %% [markdown]
# assign 함수는 total_like라는 컬럼을 만들어줍니다. 얘 값은 무엇으로 해줘! 라는 시리즈를 넣습니다.

# %%
movies_fb=movies_fb.assign(total_likes=movies_fb.sum(axis=1))
movies_fb.head()
# Out:
#    director_facebook_likes  actor_3_facebook_likes  actor_1_facebook_likes  \
# 0                      0.0                   855.0                  1000.0
# 1                    563.0                  1000.0                 40000.0
# 2                      0.0                   161.0                 11000.0
# 3                  22000.0                 23000.0                 27000.0
# 4                    131.0                     NaN                   131.0
#
#    cast_total_facebook_likes  actor_2_facebook_likes  movie_facebook_likes  \
# 0                       4834                   936.0                 33000
# 1                      48350                  5000.0                     0
# 2                      11700                   393.0                 85000
# 3                     106759                 23000.0                164000
# 4                        143                    12.0                     0
#
#    total_likes
# 0      40625.0
# 1      94913.0
# ...

# %% [markdown]
# 컬럼을 지워볼게요.
# drop 함수나 del 함수를 쓸 수 있습니다.

# %%
movies_fb.drop(columns='total_likes').head()
# Out:
#    director_facebook_likes  actor_3_facebook_likes  actor_1_facebook_likes  \
# 0                      0.0                   855.0                  1000.0
# 1                    563.0                  1000.0                 40000.0
# 2                      0.0                   161.0                 11000.0
# 3                  22000.0                 23000.0                 27000.0
# 4                    131.0                     NaN                   131.0
#
#    cast_total_facebook_likes  actor_2_facebook_likes  movie_facebook_likes
# 0                       4834                   936.0                 33000
# 1                      48350                  5000.0                     0
# 2                      11700                   393.0                 85000
# 3                     106759                 23000.0                164000
# 4                        143                    12.0                     0

# %% [markdown]
# 하지만 df 계열의 함수적 접근법이 아니고, df를 반환하지 않으니 될수있으면 del 보다는 drop을 쓰는것을 추천드립니다.

# %%
del movies_fb['total_likes']
