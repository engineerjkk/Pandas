# %%
import pandas as pd
import numpy as np

# %%
url='https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD_%EC%A0%9C19%EB%8C%80_%EB%8C%80%ED%86%B5%EB%A0%B9_%EC%84%A0%EA%B1%B0'

# %%
dfs=pd.read_html(url)

# %%
len(dfs)
# Out:
# 20

# %%
dfs[9]
# Out:
#             조사 기관          조사 기간        응답 인원  더불어민주당   자유한국당    국민의당   바른정당  \
#             조사 기관          조사 기간        응답 인원     문재인     홍준표     안철수    유승민
# 0        알앤써치[24]    4월 3일-4월 4일       1,708명  40.8 %  12.6 %  30.9 %  2.8 %
# 1       한국리서치[25]          4월 4일       1,000명  39.1 %   8.6 %  31.8 %  3.8 %
# 2        리얼미터[26]          4월 4일       1,000명  41.3 %   9.2 %  34.5 %  3.0 %
# 3        엠브레인[27]          4월 4일       1,042명  38.0 %  10.4 %  34.4 %  2.1 %
# 4        중앙일보[28]    4월 4일-4월 5일       1,500명  38.4 %   9.6 %  34.9 %  2.7 %
# 5        한국갤럽[29]    4월 4일-4월 6일       1,005명  38.0 %   7.0 %  35.0 %  4.0 %
# 6        리서치뷰[30]    4월 4일-4월 6일       1,012명  42.4 %  10.3 %  35.1 %  2.5 %
# 7      리서치플러스[31]    4월 7일-4월 8일       1,023명  37.7 %   6.6 %  37.7 %  2.1 %
# 8     리서치앤리서치[32]    4월 7일-4월 8일       1,500명  35.2 %   7.4 %  34.5 %  2.8 %
# 9       칸타퍼블릭[33]    4월 7일-4월 8일       2,300명  35.7 %   7.2 %  37.5 %  2.6 %
# ...

# %%
movie=pd.read_csv('data/movie.csv')

# %% [markdown]
# 현재 movie.csv의 데이터 용량은 1.1MB입니다.
# 불필요하게 float64 데이터가 많이 있습니다. 이 부분을 float16으로 바꾸어보겠습니다.

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
# ...

# %%
movie = pd.read_csv('data/movie.csv', nrows=1000,
 dtype={
 'num_critic_for_reviews': np.float16,
 'duration': np.float16,
 'director_facebook_likes': np.float16,
 'actor_3_facebook_likes ': np.float16,
 'actor_1_facebook_likes': np.float16,
 'gross': np.float16,
 'facenumber_in_poster ': np.int16,
 'num_user_for_reviews ': np.int16,
 'facenumber_in_poster ': np.int16,
 'budget ': np.int16,
  'title_year ': np.int16,
  'actor_2_facebook_likes ': np.int16,
    'imdb_score ': np.int16,
'aspect_ratio  ': np.int16,
     
 })

# %% [markdown]
# 메모리가 189.6KB로 절약됐습니다.

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      997 non-null    object
#  1   director_name              982 non-null    object
#  2   num_critic_for_reviews     998 non-null    float16
#  3   duration                   997 non-null    float16
#  4   director_facebook_likes    982 non-null    float16
#  5   actor_3_facebook_likes     998 non-null    float64
#  6   actor_2_name               999 non-null    object
#  7   actor_1_facebook_likes     1000 non-null   float16
#  8   gross                      965 non-null    float16
#  9   genres                     1000 non-null   object
#  10  actor_1_name               1000 non-null   object
#  11  movie_title                1000 non-null   object
#  12  num_voted_users            1000 non-null   int64
# ...

# %% [markdown]
# 17%로 감소하였습니다.

# %%
round(189600/1100000,2)
# Out:
# 0.17

# %% [markdown]
# object가 명목형 변수로 나타내는 것이 아닌, category 형태로 변환하면 메모리를 저장할 수 있다.

# %% [markdown]
# 또는 chunksize 설정으로 데이터를 쪼개수 불러올 수 있습니다.  chunk를 200으로 설정해 줌으로써, 1000개의 데이터를 5번씩 쪼개서 불러오는 것입니다.

# %%
movie = pd.read_csv('data/movie.csv', nrows=1000,chunksize=200)

# %%
def process(df):
    return f'processed {df.shape} shape of df'

# %%
for chunk in movie:
    print(process(chunk))
# Out:
# processed (200, 28) shape of df
# processed (200, 28) shape of df
# processed (200, 28) shape of df
# processed (200, 28) shape of df
# processed (200, 28) shape of df
